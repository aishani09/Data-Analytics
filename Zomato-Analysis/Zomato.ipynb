# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv(r"D:\\Downloads\\archive (1)\\zomato.csv", encoding='ISO-8859-1')

df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
city_count = df['City'].value_counts().head(10)
plt.figure(figsize=(10,6))
city_count.plot(kind='bar', color='teal')
plt.title('Top 10 Cities with the Most Restaurants')
plt.xlabel('City')
plt.ylabel('Number of Restaurants')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.hist(df['Average Cost for two'], bins=30, color='orange')
plt.title('Distribution of Average Cost for Two')
plt.xlabel('Average Cost')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.hist(df['Aggregate rating'], bins=20, color='green')
plt.title('Distribution of Restaurant Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

numeric_df = df.select_dtypes(include=['float64', 'int64'])
corr_matrix = numeric_df.corr()

plt.figure(figsize=(10,6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
delivery_count = df['Has Online delivery'].value_counts()
plt.figure(figsize=(8,6))
delivery_count.plot(kind='pie', autopct='%1.1f%%', colors=['lightblue', 'pink'], labels=['No', 'Yes'])
plt.title('Restaurant Availability by Online Delivery')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Price range', y='Aggregate rating', data=df)
plt.title('Price Range vs Aggregate Rating')
plt.xlabel('Price Range')
plt.ylabel('Rating')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Check unique values in the 'Rating color' column
unique_rating_colors = df['Rating color'].unique()
print("Unique Rating Colors:", unique_rating_colors)

# Define a mapping of rating colors to their respective colors
color_mapping = {
    'Red': 'red',               # Poor
    'Orange': 'orange',         # Average
    'Yellow': 'yellow',         # Good
    'Green': 'green',           # Very Good
    'Dark Green': 'darkgreen',  # Excellent
    'Grey': 'grey',             # No rating
    'White': 'lightgrey'        # Example additional mapping for 'White'
    # Add any other colors that may be present in the dataset
}

# Count the number of restaurants per rating color
rating_color_counts = df['Rating color'].value_counts()

# Create a color list based on the index of the rating colors
colors = [color_mapping[color] for color in rating_color_counts.index]

# Plot the distribution
plt.figure(figsize=(10,6))
sns.barplot(x=rating_color_counts.index, y=rating_color_counts.values, palette=colors)
plt.title('Distribution of Restaurants Based on Rating Color')
plt.xlabel('Rating Color')
plt.ylabel('Number of Restaurants')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()
# Out:
# Unique Rating Colors: ['Dark Green' 'Green' 'Yellow' 'Orange' 'White' 'Red']
# C:\Users\iamai\AppData\Local\Temp\ipykernel_67536\1567175538.py:29: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
from collections import Counter

cuisine_list = df['Cuisines'].dropna().str.split(', ').sum()
top_cuisines = Counter(cuisine_list).most_common(10)
cuisines_df = pd.DataFrame(top_cuisines, columns=['Cuisine', 'Count'])
plt.figure(figsize=(10,6))
sns.barplot(x='Cuisine', y='Count', data=cuisines_df)
plt.title('Top 10 Cuisines Offered')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['Votes'], df['Aggregate rating'], alpha=0.5, color='purple')
plt.title('Votes vs Aggregate Rating')
plt.xlabel('Votes')
plt.ylabel('Rating')
plt.show()

# %%
table_booking = df['Has Table booking'].value_counts()
plt.figure(figsize=(8,6))
table_booking.plot(kind='pie', autopct='%1.1f%%', colors=['lightcoral', 'skyblue'], labels=['No', 'Yes'])
plt.title('Restaurants with Table Booking')
plt.ylabel('')
plt.show()

# %%
top_cities = df['City'].value_counts().head(5).index
plt.figure(figsize=(12,6))
sns.boxplot(x='City', y='Aggregate rating', data=df[df['City'].isin(top_cities)])
plt.title('Restaurant Ratings Based on City')
plt.xlabel('City')
plt.ylabel('Rating')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.scatter(df['Average Cost for two'], df['Aggregate rating'], alpha=0.5, color='green')
plt.title('Average Cost for Two vs Aggregate Rating')
plt.xlabel('Average Cost for Two')
plt.ylabel('Rating')
plt.show()

# %%
locality_count = df['Locality'].value_counts().head(10)
plt.figure(figsize=(10,6))
locality_count.plot(kind='bar', color='indigo')
plt.title('Top 10 Localities with the Most Restaurants')
plt.xlabel('Locality')
plt.ylabel('Number of Restaurants')
plt.show()

# %%
selected_city = input("Enter the city name to filter the top 10 restaurants: ")

# Convert the rating column to numeric (if necessary)
df['Aggregate rating'] = pd.to_numeric(df['Aggregate rating'], errors='coerce')

# Drop rows with NaN values in 'Rating' or 'City' if any
df = df.dropna(subset=['Aggregate rating', 'City'])

# Filter the dataframe for the selected city
filtered_df = df[df['City'].str.lower() == selected_city.lower()]  # Case-insensitive match

# Check if there are any restaurants in the selected city
if filtered_df.empty:
    print(f"No restaurants found in {selected_city}. Please check the city name.")
else:
    # Sort the filtered dataframe by 'Rating' in descending order and get the top 10 restaurants
    top_10_restaurants = filtered_df.sort_values(by='Aggregate rating', ascending=False).head(10)

    # Display the top 10 restaurants
    print(f"Top 10 Restaurants in {selected_city}:")
    print(top_10_restaurants[['Restaurant Name', 'Aggregate rating']])
# Out:
# Enter the city name to filter the top 10 restaurants:  Chennai
# Top 10 Restaurants in Chennai:
#                Restaurant Name  Aggregate rating
# 822  AB's - Absolute Barbecues               4.9
# 809                    Chili's               4.8
# 823             Coal Barbecues               4.6
# 811            Fusilli Reasons               4.6
# 814           Bombay Brasserie               4.6
# 820         Basil With A Twist               4.5
# 807                Pantry d'or               4.4
# 821            Barbeque Nation               4.4
# 818                  Palmshore               4.4
# 817                 L'amandier               4.3
